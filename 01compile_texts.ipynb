# %%
print('live')
# Out:
# live

# %%
import pandas as pd
import os
import json

pd.options.display.max_colwidth = 200

data_path = '/data_volume/core_data/'
urls_folder = '/data_volume/url_data/'
tweets_folder = '/data_volume/twitter_data/mp_tweets/'

# %% [markdown]
# # compile and clean text data

# %%
#compile URL texts into single table

# urls = pd.read_parquet(data_path+'all_urls_no_title_or_blurb.parquet')
urls = pd.read_csv(data_path+'all_urls_no_title_or_blurb.csv')
url_rids = urls['url_rid']; del urls

url_texts = list()
for i, url_rid in enumerate(url_rids):
    subfolder = url_rid[:2]+'/'
    file = url_rid+'_parsed.txt'
    path = urls_folder+subfolder+file
    if os.path.isfile(path):
        with open(path, 'r') as f:
            text = f.read()
        url_texts.append((url_rid,text))
        
url_texts = pd.DataFrame(url_texts, columns = ['url_rid','text'])
url_texts.to_parquet('./data/url_texts.parquet')

# %%
# add url_texts to URLs

url_texts = pd.read_parquet('./data/url_texts.parquet')
urls = pd.read_csv(data_path+'all_urls_no_title_or_blurb.csv')
urls = urls.drop(columns = ['Unnamed: 0'])
urls = urls.merge(url_texts, on='url_rid', how='inner')
urls['time'] = pd.to_datetime(urls['first_post_time_unix']).dt.tz_localize(None)
urls = urls.drop(columns = ['first_post_time_unix'])
urls['domain'] = urls['clean_url'].apply(lambda x: urlparse(x).netloc) #add url domain to urls
urls.to_parquet('./data/urls.parquet')

# %%
#compile tweets data into single table

def extract_tweet_info(tweet_json, mp_name):
    time = tweet_json['created_at']
    text = tweet_json['text']
    tweet_id = tweet_json['id']
    user_id = tweet_json['author_id']
    n_likes = tweet_json['public_metrics']['like_count']
    n_replies = tweet_json['public_metrics']['reply_count']
    n_retweets = tweet_json['public_metrics']['retweet_count']
    n_quotes = tweet_json['public_metrics']['quote_count']
    tweet = (mp_name, tweet_id, time, text, user_id, n_likes, n_replies, n_retweets, n_quotes)
    return tweet


jsonfiles = os.listdir(tweets_folder)
tweets = list()
for file in jsonfiles:
    mp_name = file[:-5].replace('_', ' ')
    with open(tweets_folder+file, 'rb') as f:
        for line in list(f.readlines()):
            line_json = json.loads(line)
            if 'data' in line_json: #most files' lines contain a "data" field which is a list of tweets
                for tweet_json in line_json['data']:
                    tweets.append(extract_tweet_info(tweet_json, mp_name))
            elif 'text' in line_json: #some files' lines contain a tweet on each line
                tweet_json = line_json
                tweets.append(extract_tweet_info(tweet_json,mp_name))

tweets = pd.DataFrame(tweets, columns = ['mp_name', 'tweet_id', 'time', 'text', 
                                         'user_id', 'n_likes', 'n_replies', 
                                         'n_retweets', 'n_quotes'])
tweets.drop_duplicates(subset=['tweet_id','time']).reset_index(drop=True)
tweets['time'] = pd.to_datetime(tweets['time']).dt.tz_localize(None)
tweets.to_parquet('./data/mp_tweets.parquet')

# %%
#clean commons speeches

commons_speeches = pd.read_csv(data_path+'commons_speeches.csv')
commons_speeches = commons_speeches.dropna(subset=['text']).reset_index(drop=True)
commons_speeches = commons_speeches[~commons_speeches['hs_8Question'].isna() | ~commons_speeches['hs_2cUrgentQuestion'].isna()]
commons_speeches = commons_speeches[['_id','py_date','text','name','party','constituency','job']]
commons_speeches = commons_speeches.rename(columns = {'_id':'commons_speech_id','py_date':'date',
                                                      'party':'constituency', 'constituency':'party',
                                                      'name':'mp_name'})
commons_speeches['date'] = pd.to_datetime(commons_speeches['date'], format = "%Y-%m-%d").dt.tz_localize(None)
commons_speeches = commons_speeches.rename(columns = {'date':'time'})
commons_speeches['mp_name'] = commons_speeches['mp_name'].apply(lambda x: x.lower() if isinstance(x,str) else None)
commons_speeches['party'] = commons_speeches['party'].replace({'Lab/ Co-op':'Lab/Co-op'})
commons_speeches = commons_speeches.reset_index(drop=True)
commons_speeches.to_parquet('./data/commons_speeches.parquet')

# %% [markdown]
# # clean up MP names

# %%
import pandas as pd
import difflib
import re

# %%
commons_speeches = pd.read_parquet('./data/commons_speeches.parquet')
mp_tweets = pd.read_parquet('./data/mp_tweets.parquet')

# %%
#drop parenthetical notes
commons_speeches['mp_name'] = commons_speeches['mp_name'].apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", x))
mp_tweets['mp_name'] = mp_tweets['mp_name'].apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", x))

#drop honorifics and standardize unusual characters to ASCII text
commons_speeches['mp_name'] = commons_speeches['mp_name'].apply(lambda x: x.replace('. ',''
                                                                            ).replace('mr ',''
                                                                            ).replace('sir ',''
                                                                            ).replace('ms ',''
                                                                            ).replace('mrs ',''
                                                                            ).replace('dame ',''
                                                                            ).replace('dr',''
                                                                            ).replace('ᶜ','c'
                                                                            ).replace(' mc ',' mc'
                                                                            ).replace('\u2002',''
                                                                            ).replace('\u2003',''
                                                                            ).replace('’',"'"
                                                                            ).strip())

mp_tweets['mp_name'] = mp_tweets['mp_name'].apply(lambda x: x.replace('. ',''
                                                                ).replace('mr ',''
                                                                ).replace('sir ',''
                                                                ).replace('ms ',''
                                                                ).replace('mrs ',''
                                                                ).replace('dame ',''
                                                                ).replace('dr',''
                                                                ).replace('ᶜ','c'
                                                                ).replace(' mc ',' mc'
                                                                ).replace('\u2002',''
                                                                ).replace('\u2003',''
                                                                ).replace('’',"'"
                                                                ).strip())

# %%
parties = commons_speeches['party'].unique()

# %%
mps = commons_speeches['mp_name'].unique()
unmatched = mp_tweets[~(mp_tweets['mp_name'].isin(mps))]['mp_name'].unique()
possible_matches = {x:difflib.get_close_matches(x, mps) for x in unmatched}
possible_matches
# Out:
# {'graham p jones': ['graham pjones', 'graham jones', 'sarah jones'],
#  'stuart c mcdonald': ['stuart cmcdonald',
#   'stewart malcolm mcdonald',
#   'stuart blair donaldson'],
#  'apsana begum': [],
#  'paul maskey': ['paul masterton', 'paul sweeney', 'paul maynard'],
#  'jonathan lord': ['jonathan edwards',
#   'jonathan reynolds',
#   'jonathan ashworth'],
#  'chris hazzard': ['chris law', 'chris heaton-harris', 'christine jardine'],
#  'tahir ali': [],
#  'jon cruddas': ['john redwood', 'joan ryan'],
#  'elisha mccallion': ['lisa cameron', 'michael fallon'],
#  'neil hudson': ['nigel huddleston', 'angela richardson', "neil o'brien"],
#  'john finucane': ['john mann', 'john nicolson', 'john hayes'],
#  'mickey brady': ['patrick grady', 'karen bradley', 'vicky ford'],
#  'michelle gildernew': ['michelle donelan', 'michael dugher', 'michael gove'],
#  'órfhlaith begley': [],
#  'francie molloy': [],
#  'tanmanjeetsingh dhesi': ['tanmanjeet singh dhesi'],
#  'roger godsiff': ['robert goodwill', 'roger gale']}

# %%
mps = mp_tweets['mp_name'].unique()
unmatched = commons_speeches[~(commons_speeches['mp_name'].isin(mps))]['mp_name'].unique()
possible_matches = {x:difflib.get_close_matches(x, mps) for x in unmatched}
possible_matches
# Out:
# {'david nuttall': ['david rutley', 'david mundell', 'david evennett'],
#  'rosie winterton': ['beth winter'],
#  'fiona mactaggart': ['fiona onasanya'],
#  'rob marris': ['rebecca harris', 'carolyn harris', 'robin millar'],
#  'speaker': ['steve baker'],
#  'eilidh whiteford': ['philippa whitford'],
#  'whiteford': ['philippa whitford'],
#  'corri wilson': ['chris williamson', 'phil wilson', 'munira wilson'],
#  'eagle': ['maria eagle'],
#  'clive betts': ['clive lewis', 'clive efford', 'liz saville roberts'],
#  'tom elliott': ['julie elliott'],
#  'ben howlett': ['ben wallace', 'ben everitt', 'ben lake'],
#  'tania mathias': ['tonia antoniazzi'],
#  'callum mccaig': [],
#  'susan elan jones': ['anew jones', 'sarah jones', 'kevan jones'],
#  'ellwood': ['tobias ellwood', 'mike wood'],
#  'geoffrey clifton-brown': ['geoffrey cox'],
#  'keith vaz': ['valerie vaz'],
#  'tasmina ahmed-sheikh': [],
#  'gareth johnson': ['caroline johnson', 'joseph johnson', 'gareth snell'],
#  'kelvin hopkins': ['rachel hopkins', 'kevin hollinrake', 'kevan jones'],
#  'robert flello': ['robert neill', 'robert halfon', 'robert largan'],
#  'glyn davies': ['geraint davies', 'philip davies', 'gareth davies'],
#  'flick ummond': ['philip hammond'],
#  'alex salmond': ['alex sobel', 'alex chalk', 'kate osamor'],
#  'theresa villiers': ['teresa pearce'],
#  'graham jones': ['graham p jones', 'sarah jones', 'gerald jones'],
#  'julian brazier': ['aian bailey', 'paula barker', 'julian smith'],
#  'ellman': ['louise ellman'],
#  'danny kinahan': [],
#  'victoria atkins': ['victoria prentis'],
#  'douglas carswell': ['douglas ross', 'douglas chapman'],
#  'eric pickles': ['martin vickers'],
#  'simon burns': ['simon baynes', 'conor burns', 'simon jupp'],
#  'charlotte leslie': ['chris leslie', 'charlotte nichols', 'charles walker'],
#  'david winnick': ['david linden', 'david ew', 'david lidington'],
#  'jane ellison': ['jane stevenson', 'jamie wallis', 'gavin williamson'],
#  'margaret ritchie': ['margaret ferrier',
#   'margaret hodge',
#   'margaret greenwood'],
#  'gregory campbell': ['alan campbell'],
#  'stuart cmcdonald': ['stuart c mcdonald',
#   'stewart malcolm mcdonald',
#   'andy mcdonald'],
#  'simon danczuk': ['simon clarke', 'simon baynes', 'simon jupp'],
#  'caroline spelman': ['caroline lucas', 'caroline flint', 'caroline ansell'],
#  'james wharton': ['jamie stone', 'james frith', 'james cartlidge'],
#  'mike freer': ['marie rimmer', 'mike kane', 'nick fletcher'],
#  'graham evans': ['graham p jones', 'graham brady', 'graham stuart'],
#  'christopher chope': ['christopher pincher'],
#  'the prime minister': [],
#  'mark menzies': ['mark henick', 'mark jenkinson', 'mark tami'],
#  'angus robertson': ['laurence robertson'],
#  'richard fuller': ['richard holden', 'richard burgon', 'richard burden'],
#  'edward argar': ['edward leigh', 'edward davey', 'edward vaizey'],
#  'chris white': ['chris philp', 'chris law', 'craig whittaker'],
#  'hurd': ['nick hurd'],
#  'oliver letwin': ['clive lewis', 'oliver dowden', 'oliver heald'],
#  'iain wright': ['julian knight'],
#  'dennis skinner': [],
#  'mark williams': ['paul williams', 'craig williams', 'gavin williamson'],
#  'mark durkan': ['mark prisk', 'mark garnier', 'mike kane'],
#  'george kerevan': ['george freeman'],
#  'baker': ['steve baker', 'ben lake'],
#  'gillan': ['cheryl gillan', 'ged killen', 'gillian keegan'],
#  'jones': ['fay jones', 'ruth jones', 'anew jones'],
#  'philip hollobone': ['phillip lee', 'philip hammond', 'philip dunne'],
#  'anew percy': ['anew lewer', 'jake berry', 'ian lavery'],
#  'gavin barwell': ['hannah bardell', 'gavin williamson', 'aaron bell'],
#  'oliver colvile': ['oliver dowden', 'oliver heald'],
#  'john pugh': ['john glen', 'john howell', 'john healey'],
#  'gavin shuker': ['david gauke'],
#  'shuker': [],
#  'greg mulholland': ['greg hands'],
#  'stewart jackson': ['stuart anderson', 'stewart hosie', 'stuart anew'],
#  'betts': [],
#  'suella fernandes': ['suella braverman', 'stella creasy'],
#  'gauke': ['david gauke'],
#  'maria caulfield': ['martin whitfield', 'rosie duffield', 'maria eagle'],
#  'chris davies': ['philip davies', 'midavies', 'chris ruane'],
#  'hammond': ['philip hammond', 'stephen hammond'],
#  'anew tyrie': ['anew bridgen', 'anew bowie', 'anew rosindell'],
#  'jim cunningham': ['alex cunningham'],
#  'cunningham': ['alex cunningham'],
#  'david mackintosh': ['david davis', 'david lidington', 'david morris'],
#  'allin-khan': ['rosena allin-khan', 'afzal khan'],
#  'philip boswell': ['phillip lee', 'paul howell', 'philip dunne'],
#  'simon kirby': ['simon baynes', 'simon hart', 'simon hoare'],
#  'jackson': ['jack omey'],
#  'steven paterson': ['owen paterson', 'steve baker', 'steven bonnar'],
#  'jeremy quin': ['jeremy hunt', 'jeremy corbyn'],
#  'james berry': ['jake berry', 'james murray', 'james gray'],
#  'david anderson': ['david hanson', 'david linden', 'david amess'],
#  'calum kerr': [],
#  'gerald howarth': ['gerald jones'],
#  'evans': ['luke evans', 'nigel evans', 'kevan jones'],
#  'david burrowes': ['david jones', 'david morris', 'david warburton'],
#  'george eustice': ['george freeman'],
#  'lewell-buck': ['emma lewell-buck'],
#  'coffey': ['ann coffey', 'thérèse coffey'],
#  'mary glindon': ['mary robinson', 'mark jenkinson'],
#  'bill wiggin': [],
#  'richard arkless': ['richard holden', 'richard burden', 'richard bacon'],
#  'anew bingham': ['anew bridgen', 'alex cunningham', 'anew bowie'],
#  'henry bellingham': [],
#  'nuttall': [],
#  'gainsborough': [],
#  'carshalton and wallington': [],
#  'charlie elphicke': ['natalie elphicke', 'charles walker', 'chris stephens'],
#  'wallace': ['ben wallace'],
#  'robert goodwill': ['robert neill', 'roger godsiff'],
#  'goodwill': [],
#  'robertson': ['robert halfon', 'robert syms', 'robert neill'],
#  'stephen pound': ['stephen hepburn', 'stephen hammond', 'stephen lloyd'],
#  'michael fallon': ['michael ellis', 'michael tomlinson', 'michael fabricant'],
#  'bob stewart': ['rory stewart', 'iain stewart', 'bob seely'],
#  'spellar': ['john spellar', 'stella creasy'],
#  'richard ax': ['richard bacon', 'richard graham', 'richard holden'],
#  'stuart blair donaldson': ['stuart c mcdonald',
#   'stuart anderson',
#   'stewart malcolm mcdonald'],
#  'lee': [],
#  'gyimah': ['sam gyimah'],
#  'hollobone': [],
#  'villiers': ['meg hillier', 'ellie reeves'],
#  'honmembers': [],
#  'helen jones': ['kevan jones', 'helen hayes', 'gerald jones'],
#  'john baron': ['john lamont', 'john mann', 'kevin barron'],
#  'davis': ['midavies', 'dan jarvis', 'david jones'],
#  'peter lilley': ['peter kyle', 'peter bottomley', 'peter bone'],
#  'walker': ['robin walker', 'thelma walker', 'charles walker'],
#  'iain duncan smith': ['alan duncan', 'julian smith', 'cat smith'],
#  'neil carmichael': ['alistair carmichael', 'neil parish', 'nicola richards'],
#  'carswell': ['caroline ansell', 'gareth snell', 'dean russell'],
#  'ahmed-sheikh': [],
#  'mike penning': ['mike gapes'],
#  'natalie mcgarry': [],
#  'heidi alexander': ['heidi allen'],
#  'fiona bruce': ['ian byrne'],
#  'victoria borwick': ['victoria prentis'],
#  'byron davies': ['geraint davies', 'gareth davies', 'wayne david'],
#  'alasdair mcdonnell': ['john mcdonnell'],
#  'kris hopkins': ['rachel hopkins'],
#  'dodds': ['nigel dodds'],
#  'ian paisley': ['aian bailey', 'shaun bailey', 'ian lavery'],
#  'ritchie': [],
#  'lady hermon': ['barry sheerman', 'layla moran', 'lisa cameron'],
#  'jeremy wright': ['jeremy hunt', 'jeremy lefroy', 'jeremy corbyn'],
#  'the attorney general': [],
#  'the solicitor general': [],
#  'murray': ['ian murray', 'james murray', 'sheryll murray'],
#  'lidington': ['david lidington'],
#  'bradshaw': ['ben bradshaw'],
#  'gibb': ['nick gibb'],
#  'jayawardena': ['ranil jayawardena'],
#  'angela watkinson': ['angela richardson',
#   'angela rayner',
#   'michael tomlinson'],
#  'hunt': ['tom hunt', 'jane hunt'],
#  'david mowat': ['david ew', 'david morris', 'david warburton'],
#  'nicola blackwood': ['ian blackford',
#   'roberta blackman-woods',
#   'colum eastwood'],
#  'dunne': [],
#  'andy burnham': [],
#  'whitford': ['philippa whitford'],
#  'ben gummer': [],
#  'ronnie campbell': ['alan campbell', 'ronnie cowan', 'aaron bell'],
#  'campbell': ['alan campbell'],
#  'owen smith': ['henry smith', 'chloe smith', 'nick smith'],
#  'karen bradley': ['ben bradley', 'karen lee', 'aian bailey'],
#  'cameron': ['lisa cameron'],
#  'williams': ['william cash', 'paul williams', 'hywel williams'],
#  'rob wilson': ['jo swinson', 'munira wilson', 'phil wilson'],
#  'wilson': ['phil wilson', 'sammy wilson', 'munira wilson'],
#  'fox': [],
#  'prisk': ['mark prisk'],
#  'raab': [],
#  'sharma': ['alok sharma', 'virena sharma', 'sue hayman'],
#  'hanson': ['david hanson', 'sharon hodgson'],
#  'davies': ['midavies', 'david ew', 'david jones'],
#  'anew mitchell': ['anew rosindell', 'angela smith', 'anew griffith'],
#  'burrowes': [],
#  'tom blenkinsop': ['mark jenkinson', 'toby perkins'],
#  'roger mullin': ['kieran mullan', 'roger gale'],
#  'lewis': ['clive lewis'],
#  'michelle thomson': ['michael tomlinson',
#   'richard thomson',
#   'michelle donelan'],
#  'chris grayling': ['chris ruane', 'chris green', 'chris bryant'],
#  'john hayes': ['helen hayes', 'john cryer', 'john howell'],
#  'sheerman': ['barry sheerman', 'helen grant', 'jesse norman'],
#  'hayes': ['helen hayes'],
#  'alan haselhurst': ['sally-ann hart', 'anew selous'],
#  'pat glass': [],
#  'edward garnier': ['mark garnier', 'edward vaizey', 'edward davey'],
#  'mak': [],
#  'thomas': ['derek thomas', 'gareth thomas', 'tom watson'],
#  'gordon henderson': ['gordon marsden', 'sharon hodgson'],
#  'mathias': [],
#  'jonathan edwards': ['jonathan lord', 'jonathan reynolds', 'ruth edwards'],
#  'anew turner': ['karl turner', 'angela rayner', 'anew murrison'],
#  'anderson': ['fleur anderson', 'stuart anderson', 'anew murrison'],
#  'vara': [],
#  'jenkin': ['mark jenkinson', 'bernard jenkin'],
#  'offord': ['matthew offord'],
#  'carmichael': ['alistair carmichael', 'michael gove', 'michael ellis'],
#  'mike weir': ['mike wood', 'mike kane', 'mike amesbury'],
#  'houghton and sunderland south': [],
#  'abbott': ['diane abbott'],
#  'whittingdale': ['john whittingdale'],
#  'blackman-woods': ['roberta blackman-woods', 'bob blackman'],
#  'chope': [],
#  'turner': ['karl turner'],
#  'ivan lewis': ['julian lewis', 'clive lewis', 'brandon lewis'],
#  'mark francois': ['mark prisk', 'mark lancaster', 'mark garnier'],
#  'johnson': ['kim johnson', 'jo swinson', 'john nicolson'],
#  'paul monaghan': ['carol monaghan', 'paul girvan', 'paul maynard'],
#  'monaghan': ['carol monaghan', 'nusrat ghani'],
#  'whitehead': ['alan whitehead'],
#  'watson': ['tom watson', 'owen paterson', 'edward timpson'],
#  'anne main': ['anne milton', 'anne mclaughlin', 'sandy martin'],
#  'gisela stuart': ['graham stuart', 'iain stewart'],
#  'david tredinnick': ['david lidington', 'david linden', 'david evennett'],
#  'baron': [],
#  'michael dugher': ['michael gove', 'michael ellis', 'michelle gildernew'],
#  'hepburn': ['stephen hepburn'],
#  'miller': ['meg hillier', 'maria miller'],
#  'daniel poulter': ['dawn butler', 'danielle rowley', 'daniel zeichner'],
#  'bailey': ['aian bailey', 'shaun bailey'],
#  'poulter': [],
#  'grahame mmorris': ['grahame morris', 'james morris', 'anna mcmorrin'],
#  'george howarth': [],
#  'claire perry': ['jake berry'],
#  'skinner': [],
#  'wragg': [],
#  'paul farrelly': ['paul flynn', 'paul scully', 'paul maskey'],
#  'anew cbowie': ['anew bowie', 'anew bridgen', 'anew jones'],
#  'ew': [],
#  'fysh': [],
#  'paul beresford': ['paul bristow', 'paula barker'],
#  'laura smith': ['eleanor smith', 'cat smith', 'julian smith'],
#  'damien moore': ['robbie moore', 'damian green', 'jamie stone'],
#  'dan poulter': ['dawn butler', 'danny kruger'],
#  'bill grant': ['helen grant', 'neil gray'],
#  'latham': ['pauline latham'],
#  'mark field': ['frank field', 'martin whitfield', 'mark garnier'],
#  'huq': [],
#  'hodgson': ['sharon hodgson'],
#  'mcvey': [],
#  'john grogan': ['john mann', 'john glen', 'john lamont'],
#  'annaliese dodds': ['anneliese dodds', 'nigel dodds'],
#  'badenoch': ['kemi badenoch'],
#  'alister jack': [],
#  'paul jsweeney': ['paul sweeney', 'paul maskey'],
#  'gerard killen': ['ged killen'],
#  'geoffrey robinson': ['mary robinson', 'geoffrey cox', 'jeffrey mdonaldson'],
#  'robinson': ['mary robinson', 'gavin robinson', 'jo swinson'],
#  'rimmer': ['marie rimmer'],
#  'tanmanjeet singh dhesi': ['tanmanjeetsingh dhesi'],
#  'clarke': ['theo clarke', 'simon clarke', 'greg clark'],
#  'henick': ['mark henick'],
#  'leslie': ['chris leslie'],
#  'sweeney': ['paul sweeney', 'seema kennedy'],
#  'hugh gaffney': [],
#  'wollaston': ['sarah wollaston'],
#  'ghani': [],
#  'graham pjones': ['graham p jones', 'sarah jones', 'gerald jones'],
#  'jack': ['jack omey'],
#  'dominic grieve': ['dominic raab', 'damian green'],
#  'bone': [],
#  'harman': ['sue hayman', 'harriet harman'],
#  'dhesi': [],
#  'kirstene hair': ['kirsten oswald', 'virena sharma'],
#  'ian liddell-grainger': [],
#  'howarth': [],
#  'trevelyan': ['anne-marie trevelyan'],
#  'mike hill': ['meg hillier', 'mick whitley', 'luke hall'],
#  'graham stringer': ['graham stuart', 'grahame morris', 'graham p jones'],
#  'dorries': ['nadine dorries', 'david morris'],
#  'jack brereton': ['jack lopresti', 'jake berry'],
#  'bacon': [],
#  'trudy harrison': ['carolyn harris', 'richard harrington'],
#  'colleen fletcher': ['nick fletcher', 'katherine fletcher'],
#  'reed': [],
#  'lammy': ['david lammy'],
#  'anew griffiths': ['anew griffith', 'nia griffith'],
#  'rees-mogg': ['jacob rees-mogg'],
#  'seely': ['bob seely'],
#  'wheeler': ['heather wheeler'],
#  'south norfolk': [],
#  'mcfadden': ['pat mcfadden'],
#  'moon': [],
#  'duncan smith': ['cat smith', 'julian smith', 'nick smith'],
#  'francois': [],
#  'murrison': ['anew murrison', 'mary robinson'],
#  'streeter': ['gary streeter', 'steve baker', 'stephen kerr'],
#  'solihull': [],
#  'leeds central (lab': [],
#  'deputy speaker': [],
#  'nicholas brown': ['nicholas soames', 'alan brown', 'richard burgon'],
#  'adam holloway': ['amanda solloway'],
#  'george hollingbery': ['meg hillier'],
#  'con': [],
#  'buck': [],
#  'mole valley': ['luke hall'],
#  'grieve': [],
#  'ian c. lucas': ['ian clucas'],
#  'margaret beckett': ['margaret ferrier',
#   'margaret hodge',
#   'margaret greenwood'],
#  'mahmood': ['khalid mahmood', 'shabana mahmood'],
#  'mr marcus jones': ['marcus jones', 'ruth jones', 'sarah jones'],
#  'mr ranil jayawardena': ['ranil jayawardena'],
#  'madam deputy speaker': [],
#  'mr shailesh vara': ['shailesh vara'],
#  'mitchell': ['michael ellis', 'michael gove'],
#  'mrs pauline latham': ['pauline latham'],
#  'sirvincecable': ['vince cable'],
#  'marshadecordova': ['marsha de cordova'],
#  'jane dodds': ['nigel dodds', 'anneliese dodds', 'james dudidge'],
#  'richard graha': ['richard graham', 'richard bacon', 'richard holden'],
#  'lisa forbes': ['liam fox', 'liz saville roberts'],
#  'jacob rees- mogg': ['jacob rees-mogg'],
#  'vaizey': ['edward vaizey'],
#  'mr steve baker': ['steve baker', 'steven bonnar', 'steve brine'],
#  'ms karen buck': ['karen buck'],
#  'mark logan': ['mark garnier', 'mark lancaster', 'marco longhi'],
#  'rob roberts': ['rob butler', 'robert syms', 'laurence robertson'],
#  'kate griffiths': ['anew griffith', 'nia griffith'],
#  'steve barclay': ['stephen barclay', 'steve baker', 'steven bonnar'],
#  'mullan': ['kieran mullan', 'lucy allan'],
#  'holly mumby-croft': [],
#  'laura trott': ['laura farris'],
#  'miss sarah dines': ['sarah jones'],
#  'miss dines': ['midavies', 'james davies'],
#  'virginia crosbie': [],
#  'jonathan gullis': ['jonathan lord',
#   'jonathan reynolds',
#   'jonathan djanogly'],
#  'spencer': ['ben spencer', 'mark spencer', 'stephen kerr'],
#  'mark fletcher': ['nick fletcher', 'mark spencer', 'mark pritchard'],
#  'james grundy': ['james gray', 'james daly', 'james murray'],
#  'perkins': ['toby perkins'],
#  'ian levy': ['ian lavery', 'aian bailey', 'anna turley'],
#  'peter gibson': ['peter bone', 'patricia gibson', 'peter grant'],
#  'wallis': ['jamie wallis'],
#  'an honmember': [],
#  'perth and north perthshire': [],
#  'lee anderson': ['fleur anderson', 'stuart anderson', 'julie marson'],
#  'ummond': [],
#  'miriam cates': ['william cash'],
#  'matt vickers': ['martin vickers', 'midavies'],
#  'morgan': ['nicky morgan', 'stephen morgan'],
#  'holden': ['richard holden'],
#  'allan dorans': ['alan duncan', 'alan brown', 'layla moran'],
#  'neale hanvey': ['helen whately', 'helen hayes'],
#  'craig willia': ['craig williams', 'chris williamson', 'craig whittaker'],
#  'harper': ['mark harper'],
#  'mohina': ['gagan mohina'],
#  'east hampshire': [],
#  'city of chester': [],
#  'karen lumley': ['karen lee', 'karen buck', 'karin smyth'],
#  'david cameron': ['david amess', 'lisa cameron', 'david hanson'],
#  'jim dowd': [],
#  'may': [],
#  'jo cox': [],
#  'stephen phillips': ['stephen gethins', 'stephen timms', 'stephen lloyd'],
#  'swire': ['hugo swire'],
#  'huw irranca-davies': [],
#  'brazier': [],
#  'martin john docherty': ['martin docherty-hughes', 'leo docherty'],
#  'george osborne': ['kate osborne', 'george freeman'],
#  'osborne': ['kate osborne'],
#  'tristram hunt': ['tom hunt'],
#  'harry harpham': ['harriet harman'],
#  'matthew hancock': ['matt hancock', 'matthew pennycook', 'matthew offord'],
#  'letwin': [],
#  'mcloughlin': ['anne mclaughlin', 'patrick mcloughlin', 'tim loughton'],
#  'swayne': ['desmond swayne'],
#  'south west devon': ['john stevenson'],
#  'spelman': ['louise ellman'],
#  'graham allen': ['graham brady', 'graham stuart', 'graham p jones'],
#  'allen': ['heidi allen'],
#  'evennett': ['david evennett'],
#  'brown': ['lyn brown', 'alan brown', 'albert owen'],
#  'gray': ['neil gray'],
#  'main': [],
#  'natascha engel': [],
#  'simpson': ['keith simpson', 'david simpson'],
#  'stuart': ['stuart anew', 'graham stuart'],
#  'pendle': [],
#  'jamie reed': ['jamie stone', 'damian green', 'james heappey'],
#  'steve rotheram': ['steve reed', 'steve brine', 'steve baker'],
#  'mcdonnell': ['john mcdonnell', 'simon fell'],
#  'nick clegg': ['nick boles', 'nick gibb', 'nick fletcher']}

# %%
manual_matches = {
    'graham jones':'graham p jones',
    'tanmanjeetsingh dhesi': 'tanmanjeet singh dhesi',
    'sirvincecable':'vince cable',
    'marshadecordova':'marsha de cordova',
}

mp_tweets['mp_name'] = mp_tweets['mp_name'].replace(manual_matches)
commons_speeches['mp_name'] = commons_speeches['mp_name'].replace(manual_matches)

# %%
unmatched_tweets = mp_tweets[~(mp_tweets['mp_name'].isin(commons_speeches['mp_name'].unique()))]
unmatched_commons = commons_speeches[~(commons_speeches['mp_name'].isin(mp_tweets['mp_name'].unique()))]
print('unmatched tweets count and frac:', len(unmatched_tweets), len(unmatched_tweets)/len(mp_tweets))
print('unmatched commons_speeches count and frac:',len(unmatched_commons), len(unmatched_commons)/len(commons_speeches))
# Out:
# unmatched tweets count and frac: 40735 0.013000458614435472
# unmatched commons_speeches count and frac: 35701 0.30240733211357324

# %%
mp_tweets.to_parquet('./data/mp_tweets.parquet')
commons_speeches.to_parquet('./data/commons_speeches.parquet')

# %% [markdown]
# # add party to mp_tweets

# %%
import pandas as pd

# %%
commons_speeches = pd.read_parquet('./data/commons_speeches.parquet')
mp_tweets = pd.read_parquet('./data/mp_tweets.parquet')

# %%
mp_tweets = mp_tweets.merge(right = commons_speeches[['mp_name','party']].drop_duplicates(), on='mp_name', how='left')

# %%
mp_tweets.to_parquet('./data/mp_tweets.parquet')

# %% [markdown]
# # add median time to commons_speeches dates

# %%
import pandas as pd

# %%
commons_speeches = pd.read_parquet('./data/commons_speeches.parquet')

# %%
#set time to Noon, as this will be closer than the default (midnight) for estimated time of day
commons_speeches['time']= commons_speeches['time'] + pd.DateOffset(hours=12)

# %%
commons_speeches.to_parquet('./data/commons_speeches.parquet')

# %%
commons_speeches['party'].value_counts().index
# Out:
# Index(['Con', 'Lab', 'SNP', 'Lab/Co-op', 'LD', 'DUP', 'Ind', 'PC', 'SDLP',
#        'UUP', 'Green', 'Change UK', 'UKIP', 'IGC', 'Alliance'],
#       dtype='object')
